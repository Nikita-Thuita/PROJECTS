# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita-Thuita/PROJECTS/blob/collab/PROJECT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load dataset
#defining file path
#fp=/content/M3_House_Worth.csv
#library(pandas)
import pandas as pd
#read csv file
fp=pd.read_csv("/content/M3_House_Worth.csv")
#fp

# %% [markdown]
# We upload the data set,define the path,call the  relevant library and import from it ,then read the file

# %%
#displaying the first few rows
fp.head()
# Out:
#    HousePrice  StoreArea  BasementArea   LawnArea HouseNetWorth
# 0      138800       29.9            75  11.223911           Low
# 1      155000       44.0           504   9.689869        Medium
# 2      152000       46.2           493  10.192613        Medium
# 3      160000       46.2           510   6.817316        Medium
# 4      226000       48.7           445  10.916215        Medium

# %% [markdown]
# showing the first 5 rows of the data set

# %%
#displaying the last few rows
fp.tail()
# Out:
#      HousePrice  StoreArea  BasementArea   LawnArea HouseNetWorth
# 311       99900       59.8             0   7.982364           Low
# 312      290000       84.4           740  10.029866          High
# 313       67000       34.6            41   9.529874           Low
# 314      260000       66.0          1300  10.388070          High
# 315       84500        8.1             0  11.454849           Low

# %% [markdown]
# showing the last few rows of the data set

# %%
fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HousePrice     316 non-null    int64
#  1   StoreArea      316 non-null    float64
#  2   BasementArea   316 non-null    int64
#  3   LawnArea       316 non-null    float64
#  4   HouseNetWorth  316 non-null    object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 12.5+ KB

# %% [markdown]
# these are the data types in the data set

# %%
#data set description
fp.describe()
# Out:
#           HousePrice   StoreArea  BasementArea    LawnArea
# count     316.000000  316.000000    316.000000  316.000000
# mean   213355.272152   48.312658    573.015823    9.913504
# std    122491.768329   24.722463    564.160849    1.558365
# min     39300.000000    1.800000      0.000000    6.213974
# 25%    115000.000000   27.000000      0.000000    9.211559
# 50%    173950.000000   47.600000    402.500000    9.922729
# 75%    294057.750000   67.300000   1107.000000   10.488359
# max    755000.000000  122.000000   2188.000000   21.539383

# %% [markdown]
# This gives us the **summary statistics** before cleaning

# %%
print(fp.shape)
# Out:
# (316, 5)

# %% [markdown]
# shows number of rows and columns

# %%
print(fp.dtypes)
# Out:
# HousePrice         int64
# StoreArea        float64
# BasementArea       int64
# LawnArea         float64
# HouseNetWorth     object
# dtype: object

# %%
#DATA CLEANING
#to check what is missing
fp.isnull()
# Out:
#      HousePrice  StoreArea  BasementArea  LawnArea  HouseNetWorth
# 0         False      False         False     False          False
# 1         False      False         False     False          False
# 2         False      False         False     False          False
# 3         False      False         False     False          False
# 4         False      False         False     False          False
# ..          ...        ...           ...       ...            ...
# 311       False      False         False     False          False
# 312       False      False         False     False          False
# 313       False      False         False     False          False
# 314       False      False         False     False          False
# 315       False      False         False     False          False
#
# [316 rows x 5 columns]

# %% [markdown]
# The head and tail have no missing values

# %%
fp.isnull().sum()
# Out:
# HousePrice       0
# StoreArea        0
# BasementArea     0
# LawnArea         0
# HouseNetWorth    0
# dtype: int64

# %% [markdown]
# There are no missing values in any column

# %%
#check for duplicates
fp.duplicated().sum()
# Out:
# 0

# %%
fp.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 311    False
# 312    False
# 313    False
# 314    False
# 315    False
# Length: 316, dtype: bool

# %% [markdown]
# There are no duplicates
